# %%
# !pip install opencv-python-headless

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#!wget -O cat.jpg https://www.google.com/url?sa=i&url=https%3A%2F%2Fnownews.seoul.co.kr%2Fnews%2FnewsView.php%3Fid%3D20240806601004&psig=AOvVaw3tx7KgN4bUPoNPEiF6ODtG&ust=1737508659228000&source=images&cd=vfe&opi=89978449&ved=0CBQQjRxqFwoTCLjLwqzShYsDFQAAAAAdAAAAABAE

file_name = 'cat.jpg'

img_color = cv2.imread(file_name, cv2.IMREAD_COLOR)

cv2_imshow(img_color)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cv2.imwrite('saved_image.jpg', img_color)
print('이미지가 저장되었습니다: saved_image.jpg')

# %%
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)

cv2.imwrite('gray_image.jpg', img_gray)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
h, w = img_color.shape[:2]
img_resized = cv2.resize(img_color, (w//2, h//2))

cv2_imshow(img_resized)

cv2.imwrite('resized_image.jpg', img_resized)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img_hsv = cv2.cvtColor(img_color, cv2.COLOR_BGR2HSV)

cv2_imshow(img_hsv)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
color_ranges = {
    'red': {'lower': (0, 100, 100), 'upper': (10, 255, 255)},
    'green': {'lower': (40, 100, 100), 'upper': (70, 255, 255)},
    'blue': {'lower': (100, 100, 100), 'upper': (130, 255, 255)},
}

user_color = 'blue'

img_hsv = cv2.cvtColor(img_color, cv2.COLOR_BGR2HSV)

lower_val = color_ranges[user_color]['lower']
upper_val = color_ranges[user_color]['upper']

mask = cv2.inRange(img_hsv, lower_val, upper_val)

img_masked = cv2.bitwise_and(img_color, img_color, mask=mask)

print(f'선택된 색상: {user_color}')
cv2_imshow(mask)
cv2_imshow(img_masked)
# Out:
# 선택된 색상: blue
# <PIL.Image.Image image mode=L size=2351x1685>
# <PIL.Image.Image image mode=RGB size=2351x1685>

# %%
blurred_gaussian = cv2.GaussianBlur(img_color, (7, 7), 0)
cv2_imshow(blurred_gaussian)
cv2.imwrite('gaussian_blur.jpg', blurred_gaussian)

blurred_median = cv2.medianBlur(img_color, 7)
cv2_imshow(blurred_median)
cv2.imwrite('median_blur.jpg', blurred_median)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
